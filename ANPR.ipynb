# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2 as cv
import os
import shutil
import ultralytics
from ultralytics import YOLO

model = YOLO('best.pt')
detection_model = YOLO('char-best.pt')

class_names = {}
characters = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
for i,c in enumerate(characters):
    class_names[i] = c

def detect_characters(plate):
    cls_list = []
    x_list = []             
    results = detection_model(plate)
    for result in results:
        plate_tensor = result.boxes.xyxy
        if plate_tensor is not None:
            for dims in plate_tensor.tolist():
                px1,py1,px2,py2 = dims
                pp1 = (int(px1), int(py1))
                pp2 = (int(px2), int(py2))
                x_list.append(px1)
            cls_tensor = result.boxes.cls
            for i in cls_tensor.tolist():
                cls_list.append(i)
            conf = sum(result.boxes.conf.tolist())/10
    return cls_list, x_list, conf

def concat_plateNum(cls_list, x_list):
    sorted_list = []
    plate_number=''
    indices = sorted(range(len(x_list)), key=lambda k: x_list[k])
    for idx in indices:
        sorted_list.append(cls_list[idx])
    for i in sorted_list:
        plate_number += str(class_names[i])
    return plate_number

video_path = 'vid3.mp4'
cap = cv.VideoCapture(video_path)

vehicles_list = []
# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    ret, frame = cap.read()
    
    if ret:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model(frame)
        
        for result in results:
            tensor = result.boxes.xyxy
            if tensor is not None:
                for dims in tensor.tolist():
                    x1,y1,x2,y2 = dims
                    cv.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0,255,0), 3)
                    cropped_frame = frame[int(y1):int(y2), int(x1):int(x2)]
                    cls_list, x_list, conf = detect_characters(cropped_frame)
                    plateNum = concat_plateNum(cls_list, x_list)                    
                    if len(plateNum)==10 :
                        text = plateNum
                        font = cv.FONT_HERSHEY_SIMPLEX
                        cv.rectangle(frame, (int(x1-30),int(y1-50)), (int(x2+30),int(y1)), (0,255,255), -1)
                        cv.putText(frame, plateNum, (int(x1 - 10), int(y1) - 20),
                                    cv.FONT_HERSHEY_SIMPLEX, 0.75, (0, 0, 0), 2)
                
        frame = cv.resize(frame, (720, 480))
        cv.imshow('Detection_video', frame)

        if cv.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv.destroyAllWindows()
# Out:
# 0: 384x640 1 class_0, 222.6ms
# Speed: 7.8ms preprocess, 222.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 2 2s, 1 B, 1 N, 1 P, 2 Ts, 1999.6ms
# Speed: 5.8ms preprocess, 1999.6ms inference, 2.3ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 229.9ms
# Speed: 8.0ms preprocess, 229.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 2 2s, 1 3, 1 B, 1 P, 2 Ts, 1195.1ms
# Speed: 4.5ms preprocess, 1195.1ms inference, 6.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 176.8ms
# Speed: 9.5ms preprocess, 176.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 3 2s, 1 3, 1 B, 1 P, 2 Ts, 1075.4ms
# Speed: 0.0ms preprocess, 1075.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 179.1ms
# Speed: 6.0ms preprocess, 179.1ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 2 2s, 1 3, 1 7, 1 B, 1 N, 1 P, 2 Ts, 1 Z, 1118.8ms
# Speed: 0.0ms preprocess, 1118.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 170.7ms
# Speed: 8.0ms preprocess, 170.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 2 2s, 1 3, 1 7, 1 9, 1 A, 1 B, 1 P, 2 Ts, 1060.1ms
# Speed: 0.0ms preprocess, 1060.1ms inference, 8.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 187.2ms
# Speed: 3.5ms preprocess, 187.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 2 2s, 1 3, 3 7s, 1 9, 1 B, 1 N, 2 Ts, 1364.5ms
# Speed: 0.0ms preprocess, 1364.5ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 153.2ms
# Speed: 4.0ms preprocess, 153.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 2 2s, 1 3, 1 9, 1 B, 1 N, 2 Ts, 1123.5ms
# Speed: 0.0ms preprocess, 1123.5ms inference, 8.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 168.9ms
# Speed: 5.5ms preprocess, 168.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 3 2s, 1 3, 1 B, 1 N, 1 P, 1 T, 1191.7ms
# Speed: 4.4ms preprocess, 1191.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 160.6ms
# Speed: 9.0ms preprocess, 160.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 3 2s, 1 3, 1 9, 1 B, 1 N, 1 T, 1250.4ms
# Speed: 2.1ms preprocess, 1250.4ms inference, 8.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 169.3ms
# Speed: 5.3ms preprocess, 169.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 2 2s, 1 3, 1 7, 1 B, 1 N, 1 P, 1 T, 1 Z, 1138.5ms
# Speed: 2.5ms preprocess, 1138.5ms inference, 8.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 138.5ms
# Speed: 7.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 2 2s, 1 3, 1 7, 1 B, 1 N, 1 P, 1 T, 1 Z, 1246.2ms
# Speed: 0.0ms preprocess, 1246.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 163.1ms
# Speed: 9.4ms preprocess, 163.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 3 2s, 1 3, 1 B, 1 N, 1 P, 1 T, 1262.8ms
# Speed: 8.1ms preprocess, 1262.8ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 177.9ms
# Speed: 8.6ms preprocess, 177.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1 1, 1 2, 1 3, 1 N, 1 P, 1 T, 1 Z, 1131.2ms
# Speed: 2.6ms preprocess, 1131.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 185.8ms
# Speed: 3.7ms preprocess, 185.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 1 2, 1 3, 1 9, 1 B, 1 N, 1 P, 1 T, 1255.6ms
# Speed: 0.0ms preprocess, 1255.6ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 169.3ms
# Speed: 0.0ms preprocess, 169.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 1 2, 1 3, 1 7, 1 B, 1 E, 1 N, 1 T, 1357.2ms
# Speed: 3.8ms preprocess, 1357.2ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 177.3ms
# Speed: 6.9ms preprocess, 177.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 1 2, 1 3, 1 N, 1 P, 1 T, 1272.9ms
# Speed: 0.0ms preprocess, 1272.9ms inference, 8.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 161.1ms
# Speed: 10.3ms preprocess, 161.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 2 2s, 1 3, 1 7, 1 N, 1 P, 1 T, 1254.5ms
# Speed: 3.0ms preprocess, 1254.5ms inference, 8.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 178.6ms
# Speed: 0.0ms preprocess, 178.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 0, 1 1, 1 2, 1 3, 1 N, 1 P, 1 T, 1305.4ms
# Speed: 8.0ms preprocess, 1305.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 class_0, 178.1ms
# Speed: 8.0ms preprocess, 178.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 0, 1 1, 1 3, 1 7, 2 9s, 1 N, 1 T, 1 Z, 1426.2ms
# Speed: 2.5ms preprocess, 1426.2ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 class_0, 152.1ms
# Speed: 9.8ms preprocess, 152.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 1 3, 1 7, 1 B, 1 E, 1 N, 1 T, 1419.4ms
# Speed: 2.4ms preprocess, 1419.4ms inference, 8.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 170.1ms
# Speed: 8.2ms preprocess, 170.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 1, 1 3, 1279.0ms
# Speed: 1.1ms preprocess, 1279.0ms inference, 8.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 (no detections), 169.3ms
# Speed: 8.0ms preprocess, 169.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.2ms
# Speed: 0.0ms preprocess, 169.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.3ms
# Speed: 2.5ms preprocess, 170.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.2ms
# Speed: 0.0ms preprocess, 172.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.9ms
# Speed: 8.6ms preprocess, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.7ms
# Speed: 2.0ms preprocess, 160.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.2ms
# Speed: 9.2ms preprocess, 153.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.4ms
# Speed: 1.2ms preprocess, 169.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.7ms
# Speed: 1.9ms preprocess, 176.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.0ms
# Speed: 4.2ms preprocess, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.3ms
# Speed: 7.3ms preprocess, 163.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.2ms
# Speed: 1.3ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.7ms
# Speed: 0.0ms preprocess, 178.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.5ms
# Speed: 4.9ms preprocess, 161.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.5ms
# Speed: 8.6ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.1ms
# Speed: 8.2ms preprocess, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 166.7ms
# Speed: 4.0ms preprocess, 166.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.6ms
# Speed: 6.1ms preprocess, 159.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.0ms
# Speed: 0.0ms preprocess, 179.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.4ms
# Speed: 9.6ms preprocess, 144.4ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.9ms
# Speed: 5.4ms preprocess, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.1ms
# Speed: 0.0ms preprocess, 162.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.8ms
# Speed: 8.2ms preprocess, 171.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.7ms
# Speed: 3.2ms preprocess, 151.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.9ms
# Speed: 2.5ms preprocess, 174.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.8ms
# Speed: 8.0ms preprocess, 154.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.4ms
# Speed: 1.3ms preprocess, 177.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.2ms
# Speed: 8.4ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.4ms
# Speed: 6.2ms preprocess, 154.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.1ms
# Speed: 2.0ms preprocess, 179.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.4ms
# Speed: 16.2ms preprocess, 162.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 202.1ms
# Speed: 10.1ms preprocess, 202.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.7ms
# Speed: 7.4ms preprocess, 147.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.7ms
# Speed: 1.0ms preprocess, 167.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 8.9ms preprocess, 153.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.0ms
# Speed: 10.2ms preprocess, 168.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.3ms
# Speed: 8.3ms preprocess, 162.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.8ms
# Speed: 8.1ms preprocess, 170.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.6ms
# Speed: 0.5ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.1ms
# Speed: 8.4ms preprocess, 155.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.7ms
# Speed: 6.2ms preprocess, 172.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.0ms
# Speed: 0.0ms preprocess, 162.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.3ms
# Speed: 2.2ms preprocess, 151.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.5ms
# Speed: 9.7ms preprocess, 161.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.0ms
# Speed: 3.8ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.8ms
# Speed: 11.9ms preprocess, 158.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.0ms
# Speed: 5.5ms preprocess, 155.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.3ms
# Speed: 5.5ms preprocess, 170.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.2ms
# Speed: 10.7ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.5ms
# Speed: 5.1ms preprocess, 162.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 193.1ms
# Speed: 2.5ms preprocess, 193.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.8ms
# Speed: 15.0ms preprocess, 177.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 139.0ms
# Speed: 8.0ms preprocess, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.9ms
# Speed: 8.0ms preprocess, 160.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.5ms
# Speed: 8.0ms preprocess, 154.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.2ms
# Speed: 1.5ms preprocess, 179.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.6ms
# Speed: 7.5ms preprocess, 154.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.8ms
# Speed: 5.3ms preprocess, 165.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.1ms
# Speed: 6.5ms preprocess, 163.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.3ms
# Speed: 7.0ms preprocess, 162.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.2ms
# Speed: 3.1ms preprocess, 162.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.3ms
# Speed: 13.1ms preprocess, 174.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.2ms
# Speed: 8.4ms preprocess, 147.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.6ms
# Speed: 9.3ms preprocess, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.3ms
# Speed: 6.2ms preprocess, 170.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.1ms
# Speed: 8.0ms preprocess, 162.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.9ms
# Speed: 5.2ms preprocess, 154.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.2ms
# Speed: 9.0ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.4ms
# Speed: 2.5ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.5ms
# Speed: 7.8ms preprocess, 162.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.1ms
# Speed: 0.0ms preprocess, 147.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.2ms
# Speed: 8.4ms preprocess, 170.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.7ms
# Speed: 8.0ms preprocess, 170.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.6ms
# Speed: 9.4ms preprocess, 177.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.5ms
# Speed: 10.8ms preprocess, 152.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.6ms
# Speed: 5.1ms preprocess, 171.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 186.2ms
# Speed: 8.7ms preprocess, 186.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 171.4ms
# Speed: 2.5ms preprocess, 171.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.5ms
# Speed: 8.0ms preprocess, 154.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.1ms
# Speed: 6.4ms preprocess, 155.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.7ms
# Speed: 6.6ms preprocess, 164.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.2ms
# Speed: 2.0ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.8ms
# Speed: 7.6ms preprocess, 154.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.6ms
# Speed: 8.0ms preprocess, 170.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.6ms
# Speed: 2.7ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.3ms
# Speed: 8.0ms preprocess, 154.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.5ms
# Speed: 6.5ms preprocess, 153.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 class_0, 170.6ms
# Speed: 8.3ms preprocess, 170.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 1149.1ms
# Speed: 0.0ms preprocess, 1149.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 169.9ms
# Speed: 4.5ms preprocess, 169.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 (no detections), 1099.8ms
# Speed: 2.5ms preprocess, 1099.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 153.5ms
# Speed: 9.3ms preprocess, 153.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 1126.3ms
# Speed: 1.1ms preprocess, 1126.3ms inference, 8.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 154.4ms
# Speed: 3.6ms preprocess, 154.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 6, 1245.6ms
# Speed: 0.0ms preprocess, 1245.6ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 161.3ms
# Speed: 9.3ms preprocess, 161.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 M, 1280.0ms
# Speed: 3.8ms preprocess, 1280.0ms inference, 8.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 178.3ms
# Speed: 8.2ms preprocess, 178.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 (no detections), 1240.4ms
# Speed: 1.7ms preprocess, 1240.4ms inference, 8.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 161.2ms
# Speed: 9.7ms preprocess, 161.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 B, 1 T, 1198.4ms
# Speed: 8.2ms preprocess, 1198.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 1 class_0, 146.3ms
# Speed: 8.0ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 0, 1 6, 1293.2ms
# Speed: 0.0ms preprocess, 1293.2ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 class_0, 162.8ms
# Speed: 5.0ms preprocess, 162.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 G, 1569.7ms
# Speed: 2.6ms preprocess, 1569.7ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 (no detections), 153.7ms
# Speed: 8.2ms preprocess, 153.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 class_0, 162.6ms
# Speed: 8.1ms preprocess, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 0, 1 6, 1 D, 1 T, 1403.0ms
# Speed: 5.5ms preprocess, 1403.0ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 137.0ms
# Speed: 5.6ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.6ms
# Speed: 8.0ms preprocess, 154.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.9ms
# Speed: 12.7ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.3ms
# Speed: 7.7ms preprocess, 153.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.4ms
# Speed: 2.4ms preprocess, 171.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 class_0, 154.1ms
# Speed: 5.1ms preprocess, 154.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 2 0s, 1 7, 1 9, 1 B, 1 T, 1518.6ms
# Speed: 6.8ms preprocess, 1518.6ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 1 class_0, 154.5ms
# Speed: 8.0ms preprocess, 154.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 7, 1 9, 1 B, 1 M, 1 Q, 1 T, 1394.8ms
# Speed: 0.0ms preprocess, 1394.8ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 174.6ms
# Speed: 10.8ms preprocess, 174.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 0, 1 B, 1740.4ms
# Speed: 4.0ms preprocess, 1740.4ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 1 class_0, 178.7ms
# Speed: 6.0ms preprocess, 178.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 2 0s, 1 7, 2 Bs, 1 Z, 940.0ms
# Speed: 3.0ms preprocess, 940.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 384x640 1 class_0, 154.4ms
# Speed: 6.0ms preprocess, 154.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 7, 1 9, 1 B, 1 C, 1358.3ms
# Speed: 0.0ms preprocess, 1358.3ms inference, 8.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 146.6ms
# Speed: 4.5ms preprocess, 146.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 5, 1 7, 1 8, 1 E, 1 W, 1289.3ms
# Speed: 8.0ms preprocess, 1289.3ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 135.8ms
# Speed: 7.6ms preprocess, 135.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 0, 1 1, 1 7, 1 M, 1418.2ms
# Speed: 8.0ms preprocess, 1418.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 (no detections), 147.0ms
# Speed: 8.0ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.2ms
# Speed: 0.0ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 class_0, 171.1ms
# Speed: 6.5ms preprocess, 171.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 7, 1 9, 1 B, 1 M, 1255.3ms
# Speed: 5.5ms preprocess, 1255.3ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 (no detections), 170.8ms
# Speed: 8.3ms preprocess, 170.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.0ms
# Speed: 0.0ms preprocess, 154.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 class_0, 179.1ms
# Speed: 4.3ms preprocess, 179.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 0, 1 3, 1 7, 1 8, 1 M, 1 P, 1265.7ms
# Speed: 0.0ms preprocess, 1265.7ms inference, 8.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 class_0, 185.7ms
# Speed: 1.0ms preprocess, 185.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 1 3, 1 7, 1 8, 1 9, 1 B, 1 M, 1027.0ms
# Speed: 3.5ms preprocess, 1027.0ms inference, 8.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 1 3, 1 7, 1 8, 1 M, 1035.2ms
# Speed: 0.0ms preprocess, 1035.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 170.5ms
# Speed: 4.4ms preprocess, 170.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 1 3, 1 7, 1 8, 1 B, 1 D, 1 W, 1048.9ms
# Speed: 3.6ms preprocess, 1048.9ms inference, 8.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 163.2ms
# Speed: 8.0ms preprocess, 163.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 1 3, 1 7, 1 8, 1 9, 1 Q, 1 W, 1000.1ms
# Speed: 0.0ms preprocess, 1000.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 138.5ms
# Speed: 2.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 0, 1 2, 1 7, 1 8, 1 W, 1117.0ms
# Speed: 0.0ms preprocess, 1117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 384x640 1 class_0, 168.9ms
# Speed: 11.3ms preprocess, 168.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 0, 2 7s, 1 8, 1 9, 1 B, 1 M, 1133.6ms
# Speed: 8.2ms preprocess, 1133.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
